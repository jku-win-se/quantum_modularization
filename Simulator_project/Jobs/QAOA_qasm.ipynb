# %%
OPENQASM 2.0;
include "qelib1.inc";

qreg q[8];

creg c0[8];


h q[0];
h q[1];
h q[2];
h q[3];
h q[4];
h q[5];
h q[6];
h q[7];
cx q[7], q[6];
rz(-9.743066934438852e-9) q[6];
cx q[7], q[6];
cx q[7], q[5];
rz(-9.743066934438852e-9) q[5];
cx q[7], q[5];
cx q[6], q[5];
rz(-9.743066934438852e-9) q[5];
cx q[6], q[5];
cx q[7], q[4];
rz(-8.023702181302584e-9) q[4];
cx q[7], q[4];
cx q[6], q[4];
rz(-8.023702181302584e-9) q[4];
cx q[6], q[4];
cx q[5], q[4];
rz(-8.023702181302584e-9) q[4];
cx q[5], q[4];
cx q[7], q[3];
rz(6.8774590125450725e-9) q[3];
cx q[7], q[3];
cx q[6], q[3];
rz(6.8774590125450725e-9) q[3];
cx q[6], q[3];
cx q[5], q[3];
rz(6.8774590125450725e-9) q[3];
cx q[5], q[3];
cx q[4], q[3];
rz(-5.73121584378756e-9) q[3];
cx q[4], q[3];
cx q[7], q[2];
rz(5.158094259408804e-9) q[2];
cx q[7], q[2];
cx q[6], q[2];
rz(5.158094259408804e-9) q[2];
cx q[6], q[2];
cx q[5], q[2];
rz(5.158094259408804e-9) q[2];
cx q[5], q[2];
cx q[4], q[2];
rz(6.8774590125450725e-9) q[2];
cx q[4], q[2];
cx q[3], q[2];
rz(-8.023702181302584e-9) q[2];
cx q[3], q[2];
cx q[7], q[1];
rz(5.158094259408804e-9) q[1];
cx q[7], q[1];
cx q[6], q[1];
rz(5.158094259408804e-9) q[1];
cx q[6], q[1];
cx q[5], q[1];
rz(5.158094259408804e-9) q[1];
cx q[5], q[1];
cx q[4], q[1];
rz(6.8774590125450725e-9) q[1];
cx q[4], q[1];
cx q[3], q[1];
rz(-8.023702181302584e-9) q[1];
cx q[3], q[1];
cx q[2], q[1];
rz(-9.743066934438852e-9) q[1];
cx q[2], q[1];
rz(-1.6543612251060553e-24) q[1];
rz(-1.6543612251060553e-24) q[2];
rz(-1.6543612251060553e-24) q[3];
rz(-3.308722450212111e-24) q[4];
rz(0) q[5];
rz(0) q[6];
rz(0) q[7];
cx q[7], q[0];
rz(5.158094259408804e-9) q[0];
cx q[7], q[0];
cx q[6], q[0];
rz(5.158094259408804e-9) q[0];
cx q[6], q[0];
cx q[5], q[0];
rz(5.158094259408804e-9) q[0];
cx q[5], q[0];
cx q[4], q[0];
rz(6.8774590125450725e-9) q[0];
cx q[4], q[0];
cx q[3], q[0];
rz(-8.023702181302584e-9) q[0];
cx q[3], q[0];
cx q[2], q[0];
rz(-9.743066934438852e-9) q[0];
cx q[2], q[0];
cx q[1], q[0];
rz(-9.743066934438852e-9) q[0];
cx q[1], q[0];
rz(-1.6543612251060553e-24) q[0];
rx(0) q[0];
rx(0) q[1];
rx(0) q[2];
rx(0) q[3];
rx(0) q[4];
rx(0) q[5];
rx(0) q[6];
rx(0) q[7];
measure q[0] -> c0[0];
measure q[1] -> c0[1];
measure q[2] -> c0[2];
measure q[3] -> c0[3];
measure q[4] -> c0[4];
measure q[5] -> c0[5];
measure q[6] -> c0[6];
measure q[7] -> c0[7];
