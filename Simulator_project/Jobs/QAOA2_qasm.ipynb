# %%
OPENQASM 2.0;
include "qelib1.inc";

qreg q[8];

creg c0[8];


h q[0];
h q[1];
h q[2];
h q[3];
h q[4];
h q[5];
h q[6];
h q[7];
cx q[7], q[6];
rz(-0.5553827647335625) q[6];
cx q[7], q[6];
cx q[7], q[5];
rz(-0.5553827647335625) q[5];
cx q[7], q[5];
cx q[6], q[5];
rz(-0.5553827647335625) q[5];
cx q[6], q[5];
cx q[7], q[4];
rz(-0.45737404154528677) q[4];
cx q[7], q[4];
cx q[6], q[4];
rz(-0.45737404154528677) q[4];
cx q[6], q[4];
cx q[5], q[4];
rz(-0.45737404154528677) q[4];
cx q[5], q[4];
cx q[7], q[3];
rz(0.39203489275310294) q[3];
cx q[7], q[3];
cx q[6], q[3];
rz(0.39203489275310294) q[3];
cx q[6], q[3];
cx q[5], q[3];
rz(0.39203489275310294) q[3];
cx q[5], q[3];
cx q[4], q[3];
rz(-0.3266957439609191) q[3];
cx q[4], q[3];
cx q[7], q[2];
rz(0.2940261695648272) q[2];
cx q[7], q[2];
cx q[6], q[2];
rz(0.2940261695648272) q[2];
cx q[6], q[2];
cx q[5], q[2];
rz(0.2940261695648272) q[2];
cx q[5], q[2];
cx q[4], q[2];
rz(0.39203489275310294) q[2];
cx q[4], q[2];
cx q[3], q[2];
rz(-0.45737404154528677) q[2];
cx q[3], q[2];
cx q[7], q[1];
rz(0.2940261695648272) q[1];
cx q[7], q[1];
cx q[6], q[1];
rz(0.2940261695648272) q[1];
cx q[6], q[1];
cx q[5], q[1];
rz(0.2940261695648272) q[1];
cx q[5], q[1];
cx q[4], q[1];
rz(0.39203489275310294) q[1];
cx q[4], q[1];
cx q[3], q[1];
rz(-0.45737404154528677) q[1];
cx q[3], q[1];
cx q[2], q[1];
rz(-0.5553827647335625) q[1];
cx q[2], q[1];
cx q[7], q[0];
rz(0.2940261695648272) q[0];
cx q[7], q[0];
cx q[6], q[0];
rz(0.2940261695648272) q[0];
cx q[6], q[0];
cx q[5], q[0];
rz(0.2940261695648272) q[0];
cx q[5], q[0];
cx q[4], q[0];
rz(0.39203489275310294) q[0];
cx q[4], q[0];
cx q[3], q[0];
rz(-0.45737404154528677) q[0];
cx q[3], q[0];
cx q[2], q[0];
rz(-0.5553827647335625) q[0];
cx q[2], q[0];
cx q[1], q[0];
rz(-0.5553827647335625) q[0];
cx q[1], q[0];
rx(1.9733620343719558) q[0];
rx(1.9733620343719558) q[1];
rx(1.9733620343719558) q[2];
rx(1.9733620343719558) q[3];
rx(1.9733620343719558) q[4];
rx(1.9733620343719558) q[5];
rx(1.9733620343719558) q[6];
rx(1.9733620343719558) q[7];
measure q[0] -> c0[0];
measure q[1] -> c0[1];
measure q[2] -> c0[2];
measure q[3] -> c0[3];
measure q[4] -> c0[4];
measure q[5] -> c0[5];
measure q[6] -> c0[6];
measure q[7] -> c0[7];
